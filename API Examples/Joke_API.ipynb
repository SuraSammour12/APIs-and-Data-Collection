# %% [markdown]
# Open Joke API 😝💬
#
# take 10 random jokes and tern them into a table

# %%
# Send a GET request to the official Joke API
import requests
import json
import pandas as pd

# The API returns 10 random jokes
url = 'http://official-joke-api.appspot.com/jokes/ten'
response = requests.get(url)

# %% [markdown]
# Data analysis using json.loads()

# %%
# Convert the response text to python objects (list if dictionaries)
jokes = json.loads(response.text)

# %%
# View a sample joke
print(jokes[0])
# Out:
# {'type': 'programming', 'setup': 'Why would a guitarist become a good programmer?', 'punchline': "He's adept at riffing in C#.", 'id': 14}

# %% [markdown]
#  Convert data to a table (DataFrame) and delete columns

# %%
# Convert jokes list into a pandas DataFrame
df_jokes = pd.DataFrame(jokes)

# Drop the 'type' and 'id' columns since they are not needed
df_jokes = df_jokes.drop(columns=['type','id'])

# Show the final DataFrame
df_jokes.head()
# Out:
#                                                setup  \
# 0    Why would a guitarist become a good programmer?
# 1  I saw a nice stereo on Craigslist for $1. Sell...
# 2            What is red and smells like blue paint?
# 3  What kind of dog lives in a particle accelerator?
# 4        What's the best thing about elevator jokes?
#
#                       punchline
# 0  He's adept at riffing in C#.
# 1      I couldn’t turn it down.
# 2                    Red paint!
# 3    A Fermilabrador Retriever.
# 4  They work on so many levels.

# %% [markdown]
# A perfect mix of "dad jokes" and "nerd humor" 🙄😅
